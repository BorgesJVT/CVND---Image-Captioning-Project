# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** We can split the architecture in two parts:
#
# *Encoder:* consists of a pre-trained CNN model with 50 layers with the purpose of image classification. So on, we remove the last classifying layer and make a stitch from the mapping features to the Decoder through an embed vector (embed_size=256).
#
# *Decoder:* takes the embedded vector of features as input, combines with the captions, also embedded, and passes through the LSTM layer as a single input tensor.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** The values has been left as it is. The normalization is required to keep the same standard as used for the pre-trained model. Cropping the image is just a strategy to increase generalization/robustness over the data, which I am not sure, but I think it is not interesting for this application, since it could lead to a losing of context in the image.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I chose the embed_size=256 and hidden_layer=512 arbitraliry, since they seems to be commonly used for those applications.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** I chose the Adam optimizer since it is the most recommeded optimizer used right now due to its faster convergence and good results.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys

# !pip install nltk
import nltk
nltk.download('punkt')

sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.6/site-packages (3.2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from nltk) (1.11.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.16s)
# creating index...
#   0%|          | 886/414113 [00:00<01:37, 4250.77it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:25<00:00, 4848.84it/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 94027533.00it/s]
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time
from workspace_utils import active_session
from model import EncoderCNN, DecoderRNN

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

torch.cuda.empty_cache()
with active_session():
    for epoch in range(1, num_epochs+1):

        for i_step in range(1, total_step+1):

            if time.time() - old_time > 60:
                old_time = time.time()
                requests.request("POST", 
                                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                                 headers={'Authorization': "STAR " + response.text})

            # Randomly sample a caption length, and sample indices with that length.
            indices = data_loader.dataset.get_train_indices()
            # Create and assign a batch sampler to retrieve a batch with the sampled indices.
            new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
            data_loader.batch_sampler.sampler = new_sampler

            # Obtain the batch.
            images, captions = next(iter(data_loader))

            # Move batch of images and captions to GPU if CUDA is available.
            images = images.to(device)
            captions = captions.to(device)

            # Zero the gradients.
            decoder.zero_grad()
            encoder.zero_grad()

            # Pass the inputs through the CNN-RNN model.
            features = encoder(images)
            outputs = decoder(features, captions)

            # Calculate the batch loss.
            loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))

            # Backward pass.
            loss.backward()

            # Update the parameters in the optimizer.
            optimizer.step()

            # Get training statistics.
            stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))

            # Print training statistics (on same line).
            print('\r' + stats, end="")
            sys.stdout.flush()

            # Print training statistics to file.
            f.write(stats + '\n')
            f.flush()

            # Print training statistics (on different line).
            if i_step % print_every == 0:
                print('\r' + stats)

        # Save the weights.
        if epoch % save_every == 0:
            torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
            torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 4.0634, Perplexity: 58.1743
# Epoch [1/3], Step [200/12942], Loss: 3.5828, Perplexity: 35.9726
# Epoch [1/3], Step [300/12942], Loss: 3.1224, Perplexity: 22.7016
# Epoch [1/3], Step [400/12942], Loss: 3.7487, Perplexity: 42.4665
# Epoch [1/3], Step [500/12942], Loss: 3.1887, Perplexity: 24.25753
# Epoch [1/3], Step [600/12942], Loss: 3.1770, Perplexity: 23.9754
# Epoch [1/3], Step [700/12942], Loss: 3.3357, Perplexity: 28.0970
# Epoch [1/3], Step [800/12942], Loss: 3.2020, Perplexity: 24.5819
# Epoch [1/3], Step [900/12942], Loss: 3.0030, Perplexity: 20.1458
# Epoch [1/3], Step [1000/12942], Loss: 3.3358, Perplexity: 28.1008
# Epoch [1/3], Step [1100/12942], Loss: 2.9652, Perplexity: 19.3988
# Epoch [1/3], Step [1200/12942], Loss: 2.7436, Perplexity: 15.5425
# Epoch [1/3], Step [1300/12942], Loss: 2.6527, Perplexity: 14.1926
# Epoch [1/3], Step [1400/12942], Loss: 2.6048, Perplexity: 13.5292
# Epoch [1/3], Step [1500/12942], Loss: 2.6351, Perplexity: 13.9445
# Epoch [1/3], Step [1600/12942], Loss: 2.7751, Perplexity: 16.0395
# Epoch [1/3], Step [1700/12942], Loss: 2.4931, Perplexity: 12.0987
# Epoch [1/3], Step [1800/12942], Loss: 2.9388, Perplexity: 18.8923
# Epoch [1/3], Step [1900/12942], Loss: 2.7822, Perplexity: 16.1541
# Epoch [1/3], Step [2000/12942], Loss: 3.1211, Perplexity: 22.6721
# Epoch [1/3], Step [2100/12942], Loss: 2.4595, Perplexity: 11.6991
# Epoch [1/3], Step [2200/12942], Loss: 2.9602, Perplexity: 19.3019
# Epoch [1/3], Step [2300/12942], Loss: 2.5923, Perplexity: 13.3601
# Epoch [1/3], Step [2400/12942], Loss: 2.3531, Perplexity: 10.5177
# Epoch [1/3], Step [2500/12942], Loss: 2.8055, Perplexity: 16.5356
# Epoch [1/3], Step [2600/12942], Loss: 3.2674, Perplexity: 26.2432
# Epoch [1/3], Step [2700/12942], Loss: 2.5670, Perplexity: 13.0273
# Epoch [1/3], Step [2800/12942], Loss: 2.6609, Perplexity: 14.3093
# Epoch [1/3], Step [2900/12942], Loss: 2.6380, Perplexity: 13.9859
# Epoch [1/3], Step [3000/12942], Loss: 3.1557, Perplexity: 23.4698
# Epoch [1/3], Step [3100/12942], Loss: 2.4131, Perplexity: 11.1687
# Epoch [1/3], Step [3200/12942], Loss: 2.5566, Perplexity: 12.8922
# Epoch [1/3], Step [3300/12942], Loss: 2.5764, Perplexity: 13.1499
# Epoch [1/3], Step [3400/12942], Loss: 2.6516, Perplexity: 14.1762
# Epoch [1/3], Step [3500/12942], Loss: 2.7634, Perplexity: 15.8544
# Epoch [1/3], Step [3600/12942], Loss: 2.3442, Perplexity: 10.4247
# Epoch [1/3], Step [3700/12942], Loss: 2.4196, Perplexity: 11.2418
# Epoch [1/3], Step [3800/12942], Loss: 2.3397, Perplexity: 10.3781
# Epoch [1/3], Step [3900/12942], Loss: 2.3061, Perplexity: 10.0348
# Epoch [1/3], Step [4000/12942], Loss: 2.3886, Perplexity: 10.8984
# Epoch [1/3], Step [4100/12942], Loss: 2.7772, Perplexity: 16.0733
# Epoch [1/3], Step [4200/12942], Loss: 2.7039, Perplexity: 14.9381
# Epoch [1/3], Step [4300/12942], Loss: 2.4614, Perplexity: 11.7217
# Epoch [1/3], Step [4400/12942], Loss: 2.3400, Perplexity: 10.3811
# Epoch [1/3], Step [4500/12942], Loss: 2.2051, Perplexity: 9.07125
# Epoch [1/3], Step [4600/12942], Loss: 2.3086, Perplexity: 10.0602
# Epoch [1/3], Step [4700/12942], Loss: 2.1752, Perplexity: 8.80380
# Epoch [1/3], Step [4800/12942], Loss: 2.9295, Perplexity: 18.7182
# Epoch [1/3], Step [4900/12942], Loss: 2.4131, Perplexity: 11.1687
# Epoch [1/3], Step [5000/12942], Loss: 2.7001, Perplexity: 14.8810
# Epoch [1/3], Step [5100/12942], Loss: 2.1841, Perplexity: 8.88291
# Epoch [1/3], Step [5200/12942], Loss: 2.2097, Perplexity: 9.11266
# Epoch [1/3], Step [5300/12942], Loss: 2.3784, Perplexity: 10.7874
# Epoch [1/3], Step [5400/12942], Loss: 2.2127, Perplexity: 9.14078
# Epoch [1/3], Step [5500/12942], Loss: 2.1897, Perplexity: 8.93218
# Epoch [1/3], Step [5600/12942], Loss: 2.7586, Perplexity: 15.7782
# Epoch [1/3], Step [5700/12942], Loss: 2.4166, Perplexity: 11.2079
# Epoch [1/3], Step [5800/12942], Loss: 2.5275, Perplexity: 12.5217
# Epoch [1/3], Step [5900/12942], Loss: 2.3186, Perplexity: 10.1613
# Epoch [1/3], Step [6000/12942], Loss: 2.1312, Perplexity: 8.42538
# Epoch [1/3], Step [6100/12942], Loss: 2.3394, Perplexity: 10.3748
# Epoch [1/3], Step [6200/12942], Loss: 2.2520, Perplexity: 9.50650
# Epoch [1/3], Step [6300/12942], Loss: 2.1152, Perplexity: 8.29134
# Epoch [1/3], Step [6400/12942], Loss: 2.2852, Perplexity: 9.82741
# Epoch [1/3], Step [6500/12942], Loss: 2.0733, Perplexity: 7.95087
# Epoch [1/3], Step [6600/12942], Loss: 2.2076, Perplexity: 9.09431
# Epoch [1/3], Step [6700/12942], Loss: 2.4405, Perplexity: 11.4789
# Epoch [1/3], Step [6800/12942], Loss: 2.1267, Perplexity: 8.38700
# Epoch [1/3], Step [6900/12942], Loss: 2.5853, Perplexity: 13.2668
# Epoch [1/3], Step [7000/12942], Loss: 2.2945, Perplexity: 9.91957
# Epoch [1/3], Step [7100/12942], Loss: 2.0916, Perplexity: 8.09765
# Epoch [1/3], Step [7200/12942], Loss: 2.5280, Perplexity: 12.5290
# Epoch [1/3], Step [7300/12942], Loss: 2.0773, Perplexity: 7.98255
# Epoch [1/3], Step [7400/12942], Loss: 2.4138, Perplexity: 11.1762
# Epoch [1/3], Step [7500/12942], Loss: 2.7012, Perplexity: 14.8970
# Epoch [1/3], Step [7600/12942], Loss: 2.2199, Perplexity: 9.20649
# Epoch [1/3], Step [7700/12942], Loss: 2.3832, Perplexity: 10.8393
# Epoch [1/3], Step [7800/12942], Loss: 2.2273, Perplexity: 9.27469
# Epoch [1/3], Step [7900/12942], Loss: 2.1157, Perplexity: 8.29550
# Epoch [1/3], Step [8000/12942], Loss: 2.7162, Perplexity: 15.1227
# Epoch [1/3], Step [8100/12942], Loss: 2.2304, Perplexity: 9.30365
# Epoch [1/3], Step [8200/12942], Loss: 2.1008, Perplexity: 8.17290
# Epoch [1/3], Step [8300/12942], Loss: 2.3650, Perplexity: 10.6442
# Epoch [1/3], Step [8400/12942], Loss: 2.4449, Perplexity: 11.5294
# Epoch [1/3], Step [8500/12942], Loss: 2.6510, Perplexity: 14.1676
# Epoch [1/3], Step [8600/12942], Loss: 2.3205, Perplexity: 10.1811
# Epoch [1/3], Step [8700/12942], Loss: 2.0282, Perplexity: 7.60047
# Epoch [1/3], Step [8800/12942], Loss: 2.0023, Perplexity: 7.40632
# Epoch [1/3], Step [8900/12942], Loss: 3.0401, Perplexity: 20.9071
# Epoch [1/3], Step [9000/12942], Loss: 2.2258, Perplexity: 9.26052
# Epoch [1/3], Step [9100/12942], Loss: 2.1781, Perplexity: 8.82990
# Epoch [1/3], Step [9200/12942], Loss: 2.5401, Perplexity: 12.6805
# Epoch [1/3], Step [9300/12942], Loss: 2.2536, Perplexity: 9.52215
# Epoch [1/3], Step [9400/12942], Loss: 2.0108, Perplexity: 7.46964
# Epoch [1/3], Step [9500/12942], Loss: 2.3038, Perplexity: 10.0124
# Epoch [1/3], Step [9600/12942], Loss: 2.2858, Perplexity: 9.83330
# Epoch [1/3], Step [9700/12942], Loss: 2.1305, Perplexity: 8.41920
# Epoch [1/3], Step [9800/12942], Loss: 2.3016, Perplexity: 9.99027
# Epoch [1/3], Step [9900/12942], Loss: 2.4303, Perplexity: 11.3625
# Epoch [1/3], Step [10000/12942], Loss: 2.1784, Perplexity: 8.8318
# Epoch [1/3], Step [10100/12942], Loss: 2.1633, Perplexity: 8.70001
# Epoch [1/3], Step [10200/12942], Loss: 2.0506, Perplexity: 7.77254
# Epoch [1/3], Step [10300/12942], Loss: 2.5688, Perplexity: 13.0500
# Epoch [1/3], Step [10400/12942], Loss: 2.1214, Perplexity: 8.34249
# Epoch [1/3], Step [10500/12942], Loss: 2.2872, Perplexity: 9.84760
# Epoch [1/3], Step [10600/12942], Loss: 1.9708, Perplexity: 7.17683
# Epoch [1/3], Step [10700/12942], Loss: 2.0670, Perplexity: 7.90106
# Epoch [1/3], Step [10800/12942], Loss: 2.1615, Perplexity: 8.68425
# Epoch [1/3], Step [10900/12942], Loss: 2.2372, Perplexity: 9.36715
# Epoch [1/3], Step [11000/12942], Loss: 2.0632, Perplexity: 7.87101
# Epoch [1/3], Step [11100/12942], Loss: 1.9986, Perplexity: 7.37885
# Epoch [1/3], Step [11200/12942], Loss: 2.1808, Perplexity: 8.85370
# Epoch [1/3], Step [11300/12942], Loss: 2.2265, Perplexity: 9.26719
# Epoch [1/3], Step [11400/12942], Loss: 2.8353, Perplexity: 17.0358
# Epoch [1/3], Step [11500/12942], Loss: 2.1733, Perplexity: 8.78749
# Epoch [1/3], Step [11600/12942], Loss: 1.9580, Perplexity: 7.085399
# Epoch [1/3], Step [11700/12942], Loss: 1.8745, Perplexity: 6.51768
# Epoch [1/3], Step [11800/12942], Loss: 2.1183, Perplexity: 8.31693
# Epoch [1/3], Step [11900/12942], Loss: 2.2174, Perplexity: 9.18310
# Epoch [1/3], Step [12000/12942], Loss: 2.0476, Perplexity: 7.74931
# Epoch [1/3], Step [12100/12942], Loss: 2.1542, Perplexity: 8.62130
# Epoch [1/3], Step [12200/12942], Loss: 1.9157, Perplexity: 6.79195
# Epoch [1/3], Step [12300/12942], Loss: 2.1150, Perplexity: 8.28950
# Epoch [1/3], Step [12400/12942], Loss: 2.0825, Perplexity: 8.02414
# Epoch [1/3], Step [12500/12942], Loss: 2.1971, Perplexity: 8.99893
# Epoch [1/3], Step [12600/12942], Loss: 3.3670, Perplexity: 28.9925
# Epoch [1/3], Step [12700/12942], Loss: 2.2143, Perplexity: 9.15462
# Epoch [1/3], Step [12800/12942], Loss: 2.1874, Perplexity: 8.91194
# Epoch [1/3], Step [12900/12942], Loss: 2.0037, Perplexity: 7.41657
# Epoch [2/3], Step [100/12942], Loss: 2.0745, Perplexity: 7.9609759
# Epoch [2/3], Step [200/12942], Loss: 2.1738, Perplexity: 8.79155
# Epoch [2/3], Step [300/12942], Loss: 2.0906, Perplexity: 8.09004
# Epoch [2/3], Step [400/12942], Loss: 2.2327, Perplexity: 9.32532
# Epoch [2/3], Step [500/12942], Loss: 2.1425, Perplexity: 8.52078
# Epoch [2/3], Step [600/12942], Loss: 2.2220, Perplexity: 9.22613
# Epoch [2/3], Step [700/12942], Loss: 2.0122, Perplexity: 7.47978
# Epoch [2/3], Step [800/12942], Loss: 2.5678, Perplexity: 13.03720
# Epoch [2/3], Step [900/12942], Loss: 2.0631, Perplexity: 7.86998
# Epoch [2/3], Step [1000/12942], Loss: 2.4198, Perplexity: 11.2437
# Epoch [2/3], Step [1100/12942], Loss: 2.3339, Perplexity: 10.3177
# Epoch [2/3], Step [1200/12942], Loss: 2.0773, Perplexity: 7.98250
# Epoch [2/3], Step [1300/12942], Loss: 2.0756, Perplexity: 7.96911
# Epoch [2/3], Step [1400/12942], Loss: 2.2139, Perplexity: 9.15127
# Epoch [2/3], Step [1500/12942], Loss: 1.9876, Perplexity: 7.29810
# Epoch [2/3], Step [1600/12942], Loss: 2.0985, Perplexity: 8.15407
# Epoch [2/3], Step [1700/12942], Loss: 2.1297, Perplexity: 8.41208
# Epoch [2/3], Step [1800/12942], Loss: 2.4743, Perplexity: 11.8737
# Epoch [2/3], Step [1900/12942], Loss: 2.0806, Perplexity: 8.00922
# Epoch [2/3], Step [2000/12942], Loss: 2.1123, Perplexity: 8.26752
# Epoch [2/3], Step [2100/12942], Loss: 1.7343, Perplexity: 5.66485
# Epoch [2/3], Step [2200/12942], Loss: 2.0545, Perplexity: 7.80319
# Epoch [2/3], Step [2300/12942], Loss: 2.4944, Perplexity: 12.1140
# Epoch [2/3], Step [2400/12942], Loss: 1.9198, Perplexity: 6.81936
# Epoch [2/3], Step [2500/12942], Loss: 2.1098, Perplexity: 8.24651
# Epoch [2/3], Step [2600/12942], Loss: 2.1343, Perplexity: 8.45151
# Epoch [2/3], Step [2700/12942], Loss: 2.0788, Perplexity: 7.99490
# Epoch [2/3], Step [2800/12942], Loss: 2.1221, Perplexity: 8.34865
# Epoch [2/3], Step [2900/12942], Loss: 2.3513, Perplexity: 10.4997
# Epoch [2/3], Step [3000/12942], Loss: 2.1371, Perplexity: 8.47515
# Epoch [2/3], Step [3100/12942], Loss: 2.0180, Perplexity: 7.52312
# Epoch [2/3], Step [3200/12942], Loss: 1.9814, Perplexity: 7.25311
# Epoch [2/3], Step [3300/12942], Loss: 2.1003, Perplexity: 8.16864
# Epoch [2/3], Step [3400/12942], Loss: 1.9952, Perplexity: 7.35357
# Epoch [2/3], Step [3500/12942], Loss: 1.8792, Perplexity: 6.54805
# Epoch [2/3], Step [3600/12942], Loss: 2.0918, Perplexity: 8.09994
# Epoch [2/3], Step [3700/12942], Loss: 2.1222, Perplexity: 8.34969
# Epoch [2/3], Step [3800/12942], Loss: 2.0958, Perplexity: 8.13236
# Epoch [2/3], Step [3900/12942], Loss: 2.1912, Perplexity: 8.94597
# Epoch [2/3], Step [4000/12942], Loss: 1.9505, Perplexity: 7.03231
# Epoch [2/3], Step [4100/12942], Loss: 2.4705, Perplexity: 11.8281
# Epoch [2/3], Step [4200/12942], Loss: 2.1947, Perplexity: 8.97741
# Epoch [2/3], Step [4300/12942], Loss: 2.1487, Perplexity: 8.57382
# Epoch [2/3], Step [4400/12942], Loss: 2.2965, Perplexity: 9.93975
# Epoch [2/3], Step [4500/12942], Loss: 2.1174, Perplexity: 8.30938
# Epoch [2/3], Step [4600/12942], Loss: 2.0035, Perplexity: 7.41506
# Epoch [2/3], Step [4700/12942], Loss: 2.2753, Perplexity: 9.73108
# Epoch [2/3], Step [4800/12942], Loss: 2.0392, Perplexity: 7.68449
# Epoch [2/3], Step [4900/12942], Loss: 2.2343, Perplexity: 9.33998
# Epoch [2/3], Step [5000/12942], Loss: 2.0870, Perplexity: 8.06044
# Epoch [2/3], Step [5100/12942], Loss: 2.1180, Perplexity: 8.31421
# Epoch [2/3], Step [5200/12942], Loss: 2.3058, Perplexity: 10.0324
# Epoch [2/3], Step [5300/12942], Loss: 1.9213, Perplexity: 6.83001
# Epoch [2/3], Step [5400/12942], Loss: 2.0518, Perplexity: 7.78166
# Epoch [2/3], Step [5500/12942], Loss: 2.6177, Perplexity: 13.7039
# Epoch [2/3], Step [5600/12942], Loss: 2.0264, Perplexity: 7.58643
# Epoch [2/3], Step [5700/12942], Loss: 2.0074, Perplexity: 7.44369
# Epoch [2/3], Step [5800/12942], Loss: 2.0661, Perplexity: 7.89387
# Epoch [2/3], Step [5900/12942], Loss: 2.0398, Perplexity: 7.68949
# Epoch [2/3], Step [6000/12942], Loss: 2.1358, Perplexity: 8.46398
# Epoch [2/3], Step [6100/12942], Loss: 2.0338, Perplexity: 7.64326
# Epoch [2/3], Step [6200/12942], Loss: 1.9749, Perplexity: 7.20574
# Epoch [2/3], Step [6300/12942], Loss: 2.0914, Perplexity: 8.09643
# Epoch [2/3], Step [6400/12942], Loss: 1.9351, Perplexity: 6.92458
# Epoch [2/3], Step [6500/12942], Loss: 2.3554, Perplexity: 10.5423
# Epoch [2/3], Step [6600/12942], Loss: 2.0195, Perplexity: 7.53473
# Epoch [2/3], Step [6700/12942], Loss: 2.1631, Perplexity: 8.69812
# Epoch [2/3], Step [6800/12942], Loss: 1.8787, Perplexity: 6.54532
# Epoch [2/3], Step [6900/12942], Loss: 2.3232, Perplexity: 10.2082
# Epoch [2/3], Step [7000/12942], Loss: 2.1349, Perplexity: 8.45655
# Epoch [2/3], Step [7100/12942], Loss: 2.0421, Perplexity: 7.70687
# Epoch [2/3], Step [7200/12942], Loss: 2.1101, Perplexity: 8.24870
# Epoch [2/3], Step [7300/12942], Loss: 1.8477, Perplexity: 6.34554
# Epoch [2/3], Step [7400/12942], Loss: 2.0827, Perplexity: 8.02611
# Epoch [2/3], Step [7500/12942], Loss: 2.0526, Perplexity: 7.78824
# Epoch [2/3], Step [7600/12942], Loss: 2.0015, Perplexity: 7.39983
# Epoch [2/3], Step [7700/12942], Loss: 2.6166, Perplexity: 13.6898
# Epoch [2/3], Step [7800/12942], Loss: 2.2691, Perplexity: 9.67067
# Epoch [2/3], Step [7900/12942], Loss: 2.3158, Perplexity: 10.1328
# Epoch [2/3], Step [8000/12942], Loss: 1.9980, Perplexity: 7.37450
# Epoch [2/3], Step [8100/12942], Loss: 2.3930, Perplexity: 10.94584
# Epoch [2/3], Step [8200/12942], Loss: 2.1670, Perplexity: 8.73173
# Epoch [2/3], Step [8300/12942], Loss: 3.0796, Perplexity: 21.7496
# Epoch [2/3], Step [8400/12942], Loss: 2.0838, Perplexity: 8.03527
# Epoch [2/3], Step [8500/12942], Loss: 2.1731, Perplexity: 8.78511
# Epoch [2/3], Step [8600/12942], Loss: 2.1977, Perplexity: 9.00421
# Epoch [2/3], Step [8700/12942], Loss: 2.0420, Perplexity: 7.70614
# Epoch [2/3], Step [8800/12942], Loss: 1.8397, Perplexity: 6.29499
# Epoch [2/3], Step [8900/12942], Loss: 2.0672, Perplexity: 7.90253
# Epoch [2/3], Step [9000/12942], Loss: 1.8860, Perplexity: 6.59311
# Epoch [2/3], Step [9100/12942], Loss: 1.9478, Perplexity: 7.01335
# Epoch [2/3], Step [9200/12942], Loss: 2.0337, Perplexity: 7.64214
# Epoch [2/3], Step [9300/12942], Loss: 2.0262, Perplexity: 7.58541
# Epoch [2/3], Step [9400/12942], Loss: 1.8986, Perplexity: 6.67672
# Epoch [2/3], Step [9500/12942], Loss: 2.2787, Perplexity: 9.76368
# Epoch [2/3], Step [9600/12942], Loss: 1.9816, Perplexity: 7.25446
# Epoch [2/3], Step [9700/12942], Loss: 1.9694, Perplexity: 7.16639
# Epoch [2/3], Step [9800/12942], Loss: 2.3532, Perplexity: 10.5197
# Epoch [2/3], Step [9900/12942], Loss: 2.0961, Perplexity: 8.13443
# Epoch [2/3], Step [10000/12942], Loss: 1.8289, Perplexity: 6.2271
# Epoch [2/3], Step [10100/12942], Loss: 2.4402, Perplexity: 11.4759
# Epoch [2/3], Step [10200/12942], Loss: 2.0055, Perplexity: 7.42999
# Epoch [2/3], Step [10300/12942], Loss: 2.1237, Perplexity: 8.36188
# Epoch [2/3], Step [10400/12942], Loss: 2.4549, Perplexity: 11.6450
# Epoch [2/3], Step [10500/12942], Loss: 1.9978, Perplexity: 7.37296
# Epoch [2/3], Step [10600/12942], Loss: 1.8590, Perplexity: 6.41736
# Epoch [2/3], Step [10700/12942], Loss: 2.1115, Perplexity: 8.26050
# Epoch [2/3], Step [10800/12942], Loss: 1.9586, Perplexity: 7.08948
# Epoch [2/3], Step [10900/12942], Loss: 2.2787, Perplexity: 9.76382
# Epoch [2/3], Step [11000/12942], Loss: 2.0136, Perplexity: 7.490269
# Epoch [2/3], Step [11100/12942], Loss: 1.9361, Perplexity: 6.93205
# Epoch [2/3], Step [11200/12942], Loss: 2.2501, Perplexity: 9.48890
# Epoch [2/3], Step [11300/12942], Loss: 1.8645, Perplexity: 6.45250
# Epoch [2/3], Step [11400/12942], Loss: 1.9910, Perplexity: 7.32256
# Epoch [2/3], Step [11500/12942], Loss: 2.0810, Perplexity: 8.01269
# Epoch [2/3], Step [11600/12942], Loss: 1.9010, Perplexity: 6.69246
# Epoch [2/3], Step [11700/12942], Loss: 1.9188, Perplexity: 6.81276
# Epoch [2/3], Step [11800/12942], Loss: 1.9937, Perplexity: 7.34276
# Epoch [2/3], Step [11900/12942], Loss: 2.0852, Perplexity: 8.04601
# Epoch [2/3], Step [12000/12942], Loss: 2.1447, Perplexity: 8.53948
# Epoch [2/3], Step [12100/12942], Loss: 1.9130, Perplexity: 6.77343
# Epoch [2/3], Step [12200/12942], Loss: 2.0008, Perplexity: 7.39502
# Epoch [2/3], Step [12300/12942], Loss: 2.2260, Perplexity: 9.26256
# Epoch [2/3], Step [12400/12942], Loss: 3.0493, Perplexity: 21.1011
# Epoch [2/3], Step [12500/12942], Loss: 1.9600, Perplexity: 7.09952
# Epoch [2/3], Step [12600/12942], Loss: 1.9816, Perplexity: 7.25437
# Epoch [2/3], Step [12700/12942], Loss: 2.2061, Perplexity: 9.08011
# Epoch [2/3], Step [12800/12942], Loss: 1.9705, Perplexity: 7.17440
# Epoch [2/3], Step [12900/12942], Loss: 1.8612, Perplexity: 6.431872
# Epoch [3/3], Step [100/12942], Loss: 1.8131, Perplexity: 6.1294113
# Epoch [3/3], Step [200/12942], Loss: 2.0476, Perplexity: 7.74939
# Epoch [3/3], Step [300/12942], Loss: 2.4202, Perplexity: 11.2480
# Epoch [3/3], Step [400/12942], Loss: 2.2399, Perplexity: 9.39267
# Epoch [3/3], Step [500/12942], Loss: 2.7772, Perplexity: 16.0747
# Epoch [3/3], Step [600/12942], Loss: 2.0436, Perplexity: 7.71823
# Epoch [3/3], Step [700/12942], Loss: 2.0739, Perplexity: 7.95544
# Epoch [3/3], Step [800/12942], Loss: 2.0584, Perplexity: 7.83357
# Epoch [3/3], Step [900/12942], Loss: 2.0783, Perplexity: 7.99122
# Epoch [3/3], Step [1000/12942], Loss: 1.8036, Perplexity: 6.0716
# Epoch [3/3], Step [1100/12942], Loss: 2.0151, Perplexity: 7.50167
# Epoch [3/3], Step [1200/12942], Loss: 2.2218, Perplexity: 9.22431
# Epoch [3/3], Step [1300/12942], Loss: 2.0755, Perplexity: 7.96820
# Epoch [3/3], Step [1400/12942], Loss: 1.9507, Perplexity: 7.03392
# Epoch [3/3], Step [1500/12942], Loss: 2.0024, Perplexity: 7.40708
# Epoch [3/3], Step [1600/12942], Loss: 2.0695, Perplexity: 7.92052
# Epoch [3/3], Step [1700/12942], Loss: 2.1381, Perplexity: 8.48297
# Epoch [3/3], Step [1800/12942], Loss: 1.9051, Perplexity: 6.72042
# Epoch [3/3], Step [1900/12942], Loss: 1.9966, Perplexity: 7.36360
# Epoch [3/3], Step [2000/12942], Loss: 2.6492, Perplexity: 14.1430
# Epoch [3/3], Step [2100/12942], Loss: 1.6958, Perplexity: 5.45122
# Epoch [3/3], Step [2200/12942], Loss: 2.3676, Perplexity: 10.6719
# Epoch [3/3], Step [2300/12942], Loss: 2.0064, Perplexity: 7.43644
# Epoch [3/3], Step [2400/12942], Loss: 1.9942, Perplexity: 7.34609
# Epoch [3/3], Step [2500/12942], Loss: 2.0013, Perplexity: 7.39875
# Epoch [3/3], Step [2600/12942], Loss: 2.5628, Perplexity: 12.9724
# Epoch [3/3], Step [2700/12942], Loss: 1.9642, Perplexity: 7.12909
# Epoch [3/3], Step [2800/12942], Loss: 1.9935, Perplexity: 7.341016
# Epoch [3/3], Step [2900/12942], Loss: 1.9344, Perplexity: 6.92020
# Epoch [3/3], Step [3000/12942], Loss: 2.0920, Perplexity: 8.10083
# Epoch [3/3], Step [3100/12942], Loss: 2.0722, Perplexity: 7.94266
# Epoch [3/3], Step [3200/12942], Loss: 2.3080, Perplexity: 10.0545
# Epoch [3/3], Step [3300/12942], Loss: 1.8870, Perplexity: 6.59942
# Epoch [3/3], Step [3400/12942], Loss: 2.1925, Perplexity: 8.95808
# Epoch [3/3], Step [3500/12942], Loss: 2.0471, Perplexity: 7.74524
# Epoch [3/3], Step [3600/12942], Loss: 2.0649, Perplexity: 7.88497
# Epoch [3/3], Step [3700/12942], Loss: 2.1658, Perplexity: 8.72176
# Epoch [3/3], Step [3800/12942], Loss: 1.8899, Perplexity: 6.61862
# Epoch [3/3], Step [3900/12942], Loss: 1.7439, Perplexity: 5.71944
# Epoch [3/3], Step [4000/12942], Loss: 1.9661, Perplexity: 7.14308
# Epoch [3/3], Step [4100/12942], Loss: 1.7569, Perplexity: 5.79444
# Epoch [3/3], Step [4200/12942], Loss: 2.0525, Perplexity: 7.78750
# Epoch [3/3], Step [4300/12942], Loss: 1.9060, Perplexity: 6.72592
# Epoch [3/3], Step [4400/12942], Loss: 2.1387, Perplexity: 8.48872
# Epoch [3/3], Step [4500/12942], Loss: 1.6854, Perplexity: 5.39446
# Epoch [3/3], Step [4600/12942], Loss: 1.9972, Perplexity: 7.36863
# Epoch [3/3], Step [4700/12942], Loss: 1.9465, Perplexity: 7.00386
# Epoch [3/3], Step [4800/12942], Loss: 1.9514, Perplexity: 7.03872
# Epoch [3/3], Step [4900/12942], Loss: 2.3568, Perplexity: 10.5570
# Epoch [3/3], Step [5000/12942], Loss: 2.1023, Perplexity: 8.18482
# Epoch [3/3], Step [5100/12942], Loss: 1.6338, Perplexity: 5.12358
# Epoch [3/3], Step [5200/12942], Loss: 2.4630, Perplexity: 11.7405
# Epoch [3/3], Step [5300/12942], Loss: 1.8486, Perplexity: 6.35064
# Epoch [3/3], Step [5400/12942], Loss: 2.0905, Perplexity: 8.088948
# Epoch [3/3], Step [5500/12942], Loss: 2.1199, Perplexity: 8.33023
# Epoch [3/3], Step [5600/12942], Loss: 1.8239, Perplexity: 6.19639
# Epoch [3/3], Step [5700/12942], Loss: 2.6618, Perplexity: 14.3227
# Epoch [3/3], Step [5800/12942], Loss: 2.1418, Perplexity: 8.51502
# Epoch [3/3], Step [5900/12942], Loss: 1.7548, Perplexity: 5.78236
# Epoch [3/3], Step [6000/12942], Loss: 2.0358, Perplexity: 7.65807
# Epoch [3/3], Step [6100/12942], Loss: 1.7839, Perplexity: 5.95313
# Epoch [3/3], Step [6200/12942], Loss: 1.7187, Perplexity: 5.57718
# Epoch [3/3], Step [6300/12942], Loss: 2.2177, Perplexity: 9.18610
# Epoch [3/3], Step [6400/12942], Loss: 1.9819, Perplexity: 7.25642
# Epoch [3/3], Step [6500/12942], Loss: 2.3888, Perplexity: 10.9009
# Epoch [3/3], Step [6600/12942], Loss: 2.2967, Perplexity: 9.94166
# Epoch [3/3], Step [6700/12942], Loss: 2.5832, Perplexity: 13.2389
# Epoch [3/3], Step [6800/12942], Loss: 1.8709, Perplexity: 6.49394
# Epoch [3/3], Step [6900/12942], Loss: 1.9223, Perplexity: 6.83663
# Epoch [3/3], Step [7000/12942], Loss: 2.0217, Perplexity: 7.55133
# Epoch [3/3], Step [7100/12942], Loss: 2.2101, Perplexity: 9.11636
# Epoch [3/3], Step [7200/12942], Loss: 2.0519, Perplexity: 7.78249
# Epoch [3/3], Step [7300/12942], Loss: 2.0142, Perplexity: 7.49498
# Epoch [3/3], Step [7400/12942], Loss: 1.8333, Perplexity: 6.25452
# Epoch [3/3], Step [7500/12942], Loss: 2.2590, Perplexity: 9.57385
# Epoch [3/3], Step [7600/12942], Loss: 1.9441, Perplexity: 6.98745
# Epoch [3/3], Step [7700/12942], Loss: 1.6524, Perplexity: 5.21959
# Epoch [3/3], Step [7800/12942], Loss: 2.3906, Perplexity: 10.9200
# Epoch [3/3], Step [7900/12942], Loss: 1.7977, Perplexity: 6.03584
# Epoch [3/3], Step [8000/12942], Loss: 2.0394, Perplexity: 7.68610
# Epoch [3/3], Step [8100/12942], Loss: 2.1465, Perplexity: 8.55497
# Epoch [3/3], Step [8200/12942], Loss: 1.9941, Perplexity: 7.34541
# Epoch [3/3], Step [8300/12942], Loss: 1.9497, Perplexity: 7.02633
# Epoch [3/3], Step [8400/12942], Loss: 1.8303, Perplexity: 6.23616
# Epoch [3/3], Step [8500/12942], Loss: 1.8225, Perplexity: 6.18745
# Epoch [3/3], Step [8600/12942], Loss: 1.8676, Perplexity: 6.47271
# Epoch [3/3], Step [8700/12942], Loss: 1.9118, Perplexity: 6.76562
# Epoch [3/3], Step [8800/12942], Loss: 1.9658, Perplexity: 7.14069
# Epoch [3/3], Step [8900/12942], Loss: 2.0425, Perplexity: 7.71026
# Epoch [3/3], Step [9000/12942], Loss: 1.9282, Perplexity: 6.87680
# Epoch [3/3], Step [9100/12942], Loss: 1.9069, Perplexity: 6.73210
# Epoch [3/3], Step [9200/12942], Loss: 2.2890, Perplexity: 9.86509
# Epoch [3/3], Step [9300/12942], Loss: 1.8754, Perplexity: 6.52339
# Epoch [3/3], Step [9400/12942], Loss: 1.9142, Perplexity: 6.78189
# Epoch [3/3], Step [9500/12942], Loss: 2.0013, Perplexity: 7.39873
# Epoch [3/3], Step [9600/12942], Loss: 1.9904, Perplexity: 7.31830
# Epoch [3/3], Step [9700/12942], Loss: 2.3946, Perplexity: 10.9636
# Epoch [3/3], Step [9800/12942], Loss: 1.9305, Perplexity: 6.89313
# Epoch [3/3], Step [9900/12942], Loss: 1.9150, Perplexity: 6.78739
# Epoch [3/3], Step [10000/12942], Loss: 2.1196, Perplexity: 8.3277
# Epoch [3/3], Step [10100/12942], Loss: 2.0401, Perplexity: 7.69122
# Epoch [3/3], Step [10200/12942], Loss: 1.8371, Perplexity: 6.27815
# Epoch [3/3], Step [10300/12942], Loss: 2.4643, Perplexity: 11.7548
# Epoch [3/3], Step [10400/12942], Loss: 2.0430, Perplexity: 7.71370
# Epoch [3/3], Step [10500/12942], Loss: 1.9078, Perplexity: 6.73851
# Epoch [3/3], Step [10600/12942], Loss: 2.0195, Perplexity: 7.53498
# Epoch [3/3], Step [10700/12942], Loss: 2.4478, Perplexity: 11.5626
# Epoch [3/3], Step [10800/12942], Loss: 1.9657, Perplexity: 7.13977
# Epoch [3/3], Step [10900/12942], Loss: 2.0910, Perplexity: 8.09289
# Epoch [3/3], Step [11000/12942], Loss: 1.9327, Perplexity: 6.90841
# Epoch [3/3], Step [11100/12942], Loss: 2.0077, Perplexity: 7.44622
# Epoch [3/3], Step [11200/12942], Loss: 1.9237, Perplexity: 6.84662
# Epoch [3/3], Step [11300/12942], Loss: 1.8565, Perplexity: 6.40163
# Epoch [3/3], Step [11400/12942], Loss: 2.1153, Perplexity: 8.29242
# Epoch [3/3], Step [11500/12942], Loss: 1.7124, Perplexity: 5.54247
# Epoch [3/3], Step [11600/12942], Loss: 2.0576, Perplexity: 7.82690
# Epoch [3/3], Step [11700/12942], Loss: 2.2981, Perplexity: 9.95502
# Epoch [3/3], Step [11800/12942], Loss: 1.8803, Perplexity: 6.55546
# Epoch [3/3], Step [11900/12942], Loss: 1.8981, Perplexity: 6.67323
# Epoch [3/3], Step [12000/12942], Loss: 1.8956, Perplexity: 6.65679
# Epoch [3/3], Step [12100/12942], Loss: 2.0218, Perplexity: 7.55233
# Epoch [3/3], Step [12200/12942], Loss: 1.8394, Perplexity: 6.29255
# Epoch [3/3], Step [12300/12942], Loss: 3.1658, Perplexity: 23.7087
# Epoch [3/3], Step [12400/12942], Loss: 1.9001, Perplexity: 6.68645
# Epoch [3/3], Step [12500/12942], Loss: 2.0119, Perplexity: 7.47733
# Epoch [3/3], Step [12600/12942], Loss: 1.8738, Perplexity: 6.51306
# Epoch [3/3], Step [12700/12942], Loss: 1.8258, Perplexity: 6.20801
# Epoch [3/3], Step [12800/12942], Loss: 1.7998, Perplexity: 6.04861
# Epoch [3/3], Step [12900/12942], Loss: 2.0267, Perplexity: 7.58919
# Epoch [3/3], Step [12942/12942], Loss: 1.9578, Perplexity: 7.08350

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
